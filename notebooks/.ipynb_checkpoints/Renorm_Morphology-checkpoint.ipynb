# %%
# Should be the final notebook for the synthetic matching routine for G77 and CVn

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys, os
from scipy.ndimage.filters import gaussian_filter
sys.path.append("../interface/")
import synthetic_functions
# %matplotlib notebook
plt.rcParams['font.family'] = "Times New Roman"

# %%
def run(path, obs, group, bounds, type='both'):
    synth_array = [pd.read_csv(path + group + filename) for filename in os.listdir(path + group)]
    filenames = [filename for filename in os.listdir(path + group)]
    return synthetic_functions.compute_synthetic_array(obs, synth_array, filenames, bounds, type)

# %%
### Read observed spectra
G77_blue = pd.read_csv("/Users/MasterD/Google Drive/Yoon_UMP/output/G77/g77-61_blue_sum.fitsnorm.dat")
CVn = pd.read_csv("/Users/MasterD/Google Drive/Yoon_UMP/output/G77/CVn_blue_may1b2b_jun1b.fitsnorm_full_niave.dat")

# %%
CVn['norm'] = gaussian_filter(CVn['norm'], sigma=0.75)

# %%
G77_synth_path = '/Users/MasterD/Google Drive/Yoon_UMP/output/dwarf/'
CVn_synth_path = '/Users/MasterD/Google Drive/Yoon_UMP/output/regroup/giant/'

# %%
bounds = [3900, 4500]

G77_BLUE_RUNS = {"group": ["GI", "GII", "GIII"],
                 "chi_square": [run(G77_synth_path, G77_blue, group, bounds, caHK_CH=True) for group in ['GI/', 'GII/', 'GIII_4.0/']]
                 }
CV_RUNS =  {"group": ["GI", "GII", "GIII"],
                "chi_square": [run(CVn_synth_path, CVn, group, bounds, caHK_CH=True) for group in ['GI/', 'GII/', 'GIII/']]} #['GI/', 'z-3.5c+2.5/', 'z-3.5c+2.75/']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-1e1f652163e5> in <module>()
#       2
#       3 G77_BLUE_RUNS = {"group": ["GI", "GII", "GIII"],
# ----> 4                  "chi_square": [run(G77_synth_path, G77_blue, group, bounds, caHK_CH=True) for group in ['GI/', 'GII/', 'GIII_4.0/']]
#       5                  }
#       6 CV_RUNS =  {"group": ["GI", "GII", "GIII"],
#
# <ipython-input-53-1e1f652163e5> in <listcomp>(.0)
#       2
#       3 G77_BLUE_RUNS = {"group": ["GI", "GII", "GIII"],
# ----> 4                  "chi_square": [run(G77_synth_path, G77_blue, group, bounds, caHK_CH=True) for group in ['GI/', 'GII/', 'GIII_4.0/']]
#       5                  }
#       6 CV_RUNS =  {"group": ["GI", "GII", "GIII"],
#
# TypeError: run() got an unexpected keyword argument 'caHK_CH'

# %%
G77_BLUE_RUNS = {"group": ["GI", "GII", "GIII"],
                 "chi_median": [run(G77_synth_path, G77_blue, group, bounds, type='median') for group in ['GI/', 'GII/', 'GIII_4.25/']],
                 "chi_mean": [run(G77_synth_path, G77_blue, group, bounds, type='mean') for group in ['GI/', 'GII/', 'GIII_4.25/']],
                 "chi_weight": [run(G77_synth_path, G77_blue, group, bounds, type='weight') for group in ['GI/', 'GII/', 'GIII_4.25/']],
                 "chi_CH": [run(G77_synth_path, G77_blue, group, bounds, type='CH') for group in ['GI/', 'GII/', 'GIII_4.25/']],
                 "chi_CAII": [run(G77_synth_path, G77_blue, group, bounds, type='CAII') for group in ['GI/', 'GII/', 'GIII_4.25/']]}


CV_RUNS =  {"group": ["GI", "GII", "GIII"],
            "chi_median": [run(CVn_synth_path, CVn, group, bounds, type='median') for group in ['GI/', 'GII/', 'GIII/']],
            "chi_mean": [run(CVn_synth_path, CVn, group, bounds, type='mean') for group in ['GI/', 'GII/', 'GIII/']],
            "chi_weight": [run(CVn_synth_path, CVn, group, bounds, type='weight') for group in ['GI/', 'GII/', 'GIII/']],
            "chi_CH": [run(CVn_synth_path, CVn, group, bounds, type='CH') for group in ['GI/', 'GII/', 'GIII/']],
            "chi_CAII": [run(CVn_synth_path, CVn, group, bounds, type='CAII') for group in ['GI/', 'GII/', 'GIII/']]}

#['GI/', 'z-3.5c+2.5/', 'z-3.5c+2.75/']

# %%
CV_RUNS['chi_square'][0] = CV_RUNS['chi_square'][0].drop([1])

# %%
fig, ax = plt.subplots(1,2, figsize=(8,3))
palette = plt.cm.jet(np.linspace(0,1,10))

###### G77 Blue

color_group = ['blue', 'green', 'orange']


width=0.

#[ax[0].plot(G77_BLUE_RUNS['chi_mean'][i].sort_values(by="temp")['temp'], 
#             G77_BLUE_RUNS['chi_mean'][i].sort_values(by="temp")['chi2'], 
#           color=color, linewidth=3, alpha=0.65, label="MEAN") for i, color in enumerate(color_group)]

#######

#[ax[0].plot(G77_BLUE_RUNS['chi_median'][i].sort_values(by="temp")['temp'], 
#             G77_BLUE_RUNS['chi_median'][i].sort_values(by="temp")['chi2'], 
#           color=color, linewidth=3, alpha=0.65, label="MEDIAN") for i, color in enumerate(color_group)]

########
[ax[0].plot(G77_BLUE_RUNS['chi_weight'][i].sort_values(by="temp")['temp'], 
             G77_BLUE_RUNS['chi_weight'][i].sort_values(by="temp")['chi2'], 
            color=color, linewidth=width, alpha=0.65, label=group_label[i]) for i, color in enumerate(color_group)]


########
[ax[0].plot(G77_BLUE_RUNS['chi_CH'][i].sort_values(by="temp")['temp'], 
             G77_BLUE_RUNS['chi_CH'][i].sort_values(by="temp")['chi2'],
            color=color, linewidth=width, linestyle="dotted",alpha=0.65, label=None) for i, color in enumerate(color_group)]


########
[ax[0].plot(G77_BLUE_RUNS['chi_CAII'][i].sort_values(by="temp")['temp'], 
            G77_BLUE_RUNS['chi_CAII'][i].sort_values(by="temp")['chi2'],
            color=color, linewidth=width, linestyle="--",alpha=0.65, label=None) for i, color in enumerate(color_group)]


[ax[0].fill_between(G77_BLUE_RUNS['chi_weight'][i].sort_values(by="temp")['temp'],
                    G77_BLUE_RUNS['chi_CH'][i].sort_values(by="temp")['chi2'],
                    G77_BLUE_RUNS['chi_CAII'][i].sort_values(by="temp")['chi2'],
                    color=color, linewidth=0,alpha=0.65, label=None) for i, color in enumerate(color_group)]




ax[0].legend()


################################################################################
'z-3.0c+1.50/', 'z-3.0c+2.0/'

[ax[1].plot(CV_RUNS['chi_weight'][i].sort_values(by="temp")['temp'], 
             CV_RUNS['chi_weight'][i].sort_values(by="temp")['chi2'], 
           color=color, linewidth=width, alpha=0.65, label ="WEIGHT") for i,color in enumerate(color_group)]

[ax[1].plot(CV_RUNS['chi_CH'][i].sort_values(by="temp")['temp'], 
             CV_RUNS['chi_CH'][i].sort_values(by="temp")['chi2'], 
           color=color, linewidth=width, alpha=0.65, linestyle="dotted",label ="CH") for i,color in enumerate(color_group)]

[ax[1].plot(CV_RUNS['chi_CAII'][i].sort_values(by="temp")['temp'], 
             CV_RUNS['chi_CAII'][i].sort_values(by="temp")['chi2'], 
           color=color, linewidth=width, alpha=0.65, linestyle="--",label ="CAII") for i,color in enumerate(color_group)]


[ax[1].fill_between(CV_RUNS['chi_weight'][i].sort_values(by="temp")['temp'],
                    gaussian_filter(CV_RUNS['chi_CH'][i].sort_values(by="temp")['chi2'], sigma=1),
                    gaussian_filter(CV_RUNS['chi_CAII'][i].sort_values(by="temp")['chi2'],sigma=1),
                    color=color, linewidth=0,alpha=0.65, label=None) for i, color in enumerate(color_group)]












ax[1].legend()


#ax[1].legend(loc='lower center', ncol=3, fancybox=True, shadow=True, bbox_to_anchor=(-0.15, -0.20))


[label.tick_params(direction="in", top=True, right=True) for label in ax]
[label.tick_params(direction="in", top=True, right=True) for label in ax]
#[label.set_ylim(0.075, 0.2) for label in ax]
ax[0].set_ylim(0.00, 0.20)
[label.set_xlim(4000., 5000.) for label in ax]


[label.set_ylabel(r"$\chi_{\nu}^2$", fontsize=14) for label in ax]
[label.set_ylabel(r"$\chi_{\nu}^2$", fontsize=14) for label in ax]
[label.set_xlabel(r"T$_{\rm eff}$ [K]", fontsize=13) for label in ax]
[label.set_xlabel(r"T$_{\rm eff}$ [K]", fontsize=13) for label in ax]

#[label.set_yscale("log") for label in ax]
plt.subplots_adjust(bottom=0.15, right=0.9, top=0.9, wspace=0.30, hspace=0.4)
#plt.savefig("plots/CV_fitting_v2.pdf", format="pdf")

props = dict(boxstyle='round', facecolor="white", alpha=0.5)
textstr = "G77-61"
#ax[0].text(0.95, 1.25, textstr, transform=ax[0].transAxes, fontsize=14,
#        verticalalignment='top', bbox=props)
ax[0].text(0.40, 0.95, textstr, transform=ax[0].transAxes, fontsize=14,
        verticalalignment='top', bbox=props)


textstr = "SDSSJ1327+3335"
#ax[1].text(0.865, 1.25, textstr, transform=ax[1].transAxes, fontsize=14,
#        verticalalignment='top', bbox=props)
ax[1].text(0.40, 0.95, textstr, transform=ax[1].transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

#plt.savefig('plots/final/morpho_class_g77_cvn.pdf', format="pdf")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
G77_synth_path = "/Users/MasterD/Google Drive/Yoon_UMP/output/G77/final/"

files = os.listdir(G77_synth_path)
temp = []
for current in files:
    temp.append(float(current.split("T")[1].split("g")[0]))
specs = [pd.read_csv(G77_synth_path + a_file) for a_file in files]
plt.figure()
cmap = plt.cm.jet(np.linspace(0,1,len(temp)))
[plt.plot(specs[i]['wave'], specs[i]['norm'], linewidth=0.75, alpha=0.45, color=cmap[index]) for index, i in enumerate(np.argsort(temp))]

plt.plot(G77_blue['wave'], G77_blue['norm'], color="black", alpha=0.85, linewidth=1.0)

plt.xlim([3900, 4500])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (3900, 4500)

# %%
CVn_synth_path = "/Users/MasterD/Google Drive/Yoon_UMP/output/CVn/final/"
files = os.listdir(CVn_synth_path)
temp = []
for current in files:
    temp.append(float(current.split(".csv")[0].split("c")[1]))
specs = [pd.read_csv(CVn_synth_path + a_file) for a_file in files]
plt.figure()
cmap = plt.cm.jet(np.linspace(0,1,len(temp)))
[plt.plot(specs[i]['wave'], specs[i]['flux'], linewidth=0.75, alpha=0.65, color=cmap[index]) for index, i in enumerate(np.argsort(temp))]

plt.plot(CVn['wave'], CVn['norm'], color="black", alpha=0.65, linewidth=0.5)

plt.xlim([3900, 4500])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (3900, 4500)

# %%
temp
# Out:
# [4200.0,
#  4200.0,
#  4200.0,
#  4200.0,
#  4200.0,
#  4200.0,
#  4200.0,
#  4200.0,
#  4200.0,
#  4200.0,
#  4200.0,
#  4200.0,
#  4200.0,
#  4200.0,
#  4200.0,
#  4200.0,
#  4200.0,
#  4200.0,
#  4200.0,
#  4200.0,
#  4200.0,
#  4200.0,
#  4200.0,
#  4200.0,
#  4200.0]

# %% [markdown]
# ### Final Parameter Fitting

# %%
G77_synth_path = "/Users/MasterD/Google Drive/Yoon_UMP/output/G77/final/"
CVn_synth_path = "/Users/MasterD/Google Drive/Yoon_UMP/output/CVn/final/"

# %%
## Store in dicts until I can figure out something better.

G77_synth_array = {"name": os.listdir(G77_synth_path),
                   "spec": [pd.read_csv(G77_synth_path + current) for current in os.listdir(G77_synth_path)]}
                   
                   
CVn_synth_array = {"name": os.listdir(CVn_synth_path),
                   "spec": [pd.read_csv(CVn_synth_path + current) for current in os.listdir(CVn_synth_path)]}

# %%
G77_synth_array['CHI_FEH'] = [synthetic_functions.determine_rChi_2(G77_blue, spec, bounds, type="CAII") for spec in G77_synth_array['spec']]
CVn_synth_array['CHI_FEH'] = [synthetic_functions.determine_rChi_2(CVn, spec, bounds, type="CAII") for spec in CVn_synth_array['spec']]

G77_synth_array['CHI2'] = [synthetic_functions.determine_rChi_2(G77_blue, spec, bounds,type="both") for spec in G77_synth_array['spec']]
CVn_synth_array['CHI2'] = [synthetic_functions.determine_rChi_2(CVn, spec, bounds, type="both") for spec in CVn_synth_array['spec']]

G77_synth_array['CHI_CH'] = [synthetic_functions.determine_rChi_2(G77_blue, spec, bounds,type="CH") for spec in G77_synth_array['spec']]
CVn_synth_array['CHI_CH'] = [synthetic_functions.determine_rChi_2(CVn, spec, bounds, type="CH") for spec in CVn_synth_array['spec']]

G77_synth_array['CHI_WEIGHT'] = [synthetic_functions.determine_rChi_2(G77_blue, spec, bounds,type="weight") for spec in G77_synth_array['spec']]
CVn_synth_array['CHI_WEIGHT'] = [synthetic_functions.determine_rChi_2(CVn, spec, bounds, type="weight") for spec in CVn_synth_array['spec']]

G77_synth_array['CHI_MEDIAN'] = [synthetic_functions.determine_rChi_2(G77_blue, spec, bounds,type="median") for spec in G77_synth_array['spec']]
CVn_synth_array['CHI_MEDIAN'] = [synthetic_functions.determine_rChi_2(CVn, spec, bounds, type="median") for spec in CVn_synth_array['spec']]

G77_synth_array['CHI_MEAN'] = [synthetic_functions.determine_rChi_2(G77_blue, spec, bounds,type="mean") for spec in G77_synth_array['spec']]
CVn_synth_array['CHI_MEAN'] = [synthetic_functions.determine_rChi_2(CVn, spec, bounds, type="mean") for spec in CVn_synth_array['spec']]

# %%
import ac
#G77_synth_array['AC'] = [ac.ac(float(name.split("csv")[0].split('.c')[1]), float(name.split("z")[1].split('c')[0])) for name in G77_synth_array['name']]

CVn_synth_array['CFE'] = [float(name.split('.csv')[0].split("c")[1]) for name in CVn_synth_array['name']]
G77_synth_array['CFE'] = [float(name.split('.csv')[0].split("c")[1]) for name in G77_synth_array['name']]

CVn_synth_array['FEH'] = [float(name.split("z")[1].split("c")[0]) for name in CVn_synth_array['name']]
G77_synth_array['FEH'] = [float(name.split("z")[1].split("c")[0]) for name in G77_synth_array['name']]
CVn_synth_array['ACE'] = [ac.ac(cur_ac, cur_feh) for cur_ac, cur_feh in zip(CVn_synth_array['CFE'], CVn_synth_array['FEH'])]
G77_synth_array['ACE'] = [ac.ac(cur_ac, cur_feh) for cur_ac, cur_feh in zip(G77_synth_array['CFE'], G77_synth_array['FEH'])]

# %%
G77_index = np.argsort(G77_synth_array['ACE'])
CVn_index = np.argsort(CVn_synth_array['ACE'])


G77_PARAMS = {'AC_CHI2':   G77_synth_array['ACE'][np.where(G77_synth_array['CHI2'] == min(G77_synth_array['CHI2']))[0][0]],
              'AC_FEH':    G77_synth_array['ACE'][np.where(G77_synth_array['CHI_FEH'] == min(G77_synth_array['CHI_FEH']))[0][0]],
              'AC_WEIGHT': G77_synth_array['ACE'][np.where(G77_synth_array['CHI_WEIGHT'] == min(G77_synth_array['CHI_WEIGHT']))[0][0]],
              'AC_MEDIAN': G77_synth_array['ACE'][np.where(G77_synth_array['CHI_MEDIAN'] == min(G77_synth_array['CHI_MEDIAN']))[0][0]],
              'AC_MEAN':   G77_synth_array['ACE'][np.where(G77_synth_array['CHI_MEAN'] == min(G77_synth_array['CHI_MEAN']))[0][0]],
              'AC_CH':     G77_synth_array['ACE'][np.where(G77_synth_array['CHI_CH'] == min(G77_synth_array['CHI_CH']))[0][0]]
             
             }

CVn_PARAMS = {'AC_CHI2':   CVn_synth_array['ACE'][np.where(CVn_synth_array['CHI2'] == min(CVn_synth_array['CHI2']))[0][0]],
              'AC_FEH':    CVn_synth_array['ACE'][np.where(CVn_synth_array['CHI_FEH'] == min(CVn_synth_array['CHI_FEH']))[0][0]],
              'AC_WEIGHT': CVn_synth_array['ACE'][np.where(CVn_synth_array['CHI_WEIGHT'] == min(CVn_synth_array['CHI_WEIGHT']))[0][0]],
              'AC_MEDIAN': CVn_synth_array['ACE'][np.where(CVn_synth_array['CHI_MEDIAN'] == min(CVn_synth_array['CHI_MEDIAN']))[0][0]],
              'AC_MEAN':   CVn_synth_array['ACE'][np.where(CVn_synth_array['CHI_MEAN'] == min(CVn_synth_array['CHI_MEAN']))[0][0]],
              'AC_CH':     CVn_synth_array['ACE'][np.where(CVn_synth_array['CHI_CH'] == min(CVn_synth_array['CHI_CH']))[0][0]]
             
             }

# %%
CV_MEDIAN = np.mean([val for val in CVn_PARAMS.values()])
G77_MEDIAN = np.mean([val for val in G77_PARAMS.values()])
CV_STD = np.std([val for val in CVn_PARAMS.values()])
G77_STD = np.std([val for val in G77_PARAMS.values()])

# %%
fig,ax = plt.subplots(1,2, figsize=(10,4))


palette = plt.cm.jet(np.linspace(0,1,6))
plot_alpha=0.65
vert_alpha=0.65

G77_index = np.argsort(G77_synth_array['ACE'])
CVn_index = np.argsort(CVn_synth_array['ACE'])


ax[0].plot([G77_synth_array['ACE'][i] for i in G77_index], [G77_synth_array['CHI2'][i] for i in G77_index], 
           label="CHI2", color=palette[0], alpha=plot_alpha)
ax[0].axvline(G77_PARAMS['AC_CHI2'], color=palette[0], alpha=vert_alpha)


ax[1].plot([CVn_synth_array['ACE'][i] for i in CVn_index], [CVn_synth_array['CHI2'][i] for i in CVn_index], 
           label="CHI2", color=palette[0], alpha=plot_alpha)
ax[1].axvline(CVn_PARAMS['AC_CHI2'], color=palette[0], alpha=vert_alpha)


# ~~~~~~~~~~~~~~~~~~~~~~~~

ax[0].plot([G77_synth_array['ACE'][i] for i in G77_index], [G77_synth_array['CHI_FEH'][i] for i in G77_index], 
           label="CHI_FEH", color=palette[1], alpha=plot_alpha)
ax[0].axvline(G77_PARAMS['AC_FEH'], color=palette[1], alpha=vert_alpha)


ax[1].plot([CVn_synth_array['ACE'][i] for i in CVn_index], [CVn_synth_array['CHI_FEH'][i] for i in CVn_index], 
           label="CHI_FEH", color=palette[1])
ax[1].axvline(CVn_PARAMS['AC_FEH'], color=palette[1], alpha=vert_alpha)

# ~~~~~~~~~~~~~~~~~~~~~~~~


ax[0].plot([G77_synth_array['ACE'][i] for i in G77_index], [G77_synth_array['CHI_CH'][i] for i in G77_index], 
           label="CHI_CH", color=palette[2], alpha=plot_alpha)
ax[0].axvline(G77_PARAMS['AC_CH'], color=palette[2], alpha=vert_alpha)


ax[1].plot([CVn_synth_array['ACE'][i] for i in CVn_index], [CVn_synth_array['CHI_CH'][i] for i in CVn_index], 
           label="CHI_CH", color=palette[2])
ax[1].axvline(CVn_PARAMS['AC_CH'], color=palette[2], alpha=vert_alpha)


# ~~~~~~~~~~~~~~~~~~~~~~~~

ax[0].plot([G77_synth_array['ACE'][i] for i in G77_index], [G77_synth_array['CHI_WEIGHT'][i] for i in G77_index],
           color=palette[3], linestyle="--",label="CHI_WEIGHT", alpha=plot_alpha)
ax[0].axvline(G77_PARAMS['AC_WEIGHT'], color=palette[3], alpha=vert_alpha)


ax[1].plot([CVn_synth_array['ACE'][i] for i in CVn_index], [CVn_synth_array['CHI_WEIGHT'][i] for i in CVn_index],
           color=palette[3], linestyle="--",label="CHI_WEIGHT")
ax[1].axvline(CVn_PARAMS['AC_WEIGHT'], color=palette[3], alpha=vert_alpha)

# ~~~~~~~~~~~~~~~~~~~~~~~~


ax[0].plot([G77_synth_array['ACE'][i] for i in G77_index], [G77_synth_array['CHI_MEAN'][i] for i in G77_index],
           color=palette[4], linestyle="--", label="CHI_MEAN", alpha=plot_alpha)
ax[0].axvline(G77_PARAMS['AC_MEAN'], color=palette[4], alpha=vert_alpha)


ax[1].plot([CVn_synth_array['ACE'][i] for i in CVn_index], [CVn_synth_array['CHI_MEAN'][i] for i in CVn_index],
           color=palette[4], linestyle="--", label="CHI_MEAN")
ax[1].axvline(CVn_PARAMS['AC_MEAN'], color=palette[4], alpha=vert_alpha)


# ~~~~~~~~~~~~~~~~~~~~~~~~


ax[0].plot([G77_synth_array['ACE'][i] for i in G77_index], [G77_synth_array['CHI_MEDIAN'][i] for i in G77_index],
           color=palette[5], linestyle="--", label="CHI_MEDIAN", alpha=plot_alpha)
ax[0].axvline(G77_PARAMS['AC_MEDIAN'], color=palette[5], alpha=vert_alpha)


ax[1].plot([CVn_synth_array['ACE'][i] for i in CVn_index], [CVn_synth_array['CHI_MEDIAN'][i] for i in CVn_index],
           color=palette[5], linestyle="--", label="CHI_MEDIAN")
ax[1].axvline(CVn_PARAMS['AC_MEDIAN'], color=palette[5], alpha=vert_alpha)

# ~~~~~~~~~~~~~~~~~~~~~~~~
ac_array = np.linspace
ax[0].axvline(G77_MEDIAN, color="grey", linewidth=3.)
ax[1].axvline(CV_MEDIAN, color="grey", linewidth=3.)

ax[0].fill_between(np.linspace(G77_MEDIAN - G77_STD, G77_MEDIAN+G77_STD, 10),np.zeros(10), np.ones(10), color="grey", alpha=0.35)
ax[1].fill_between(np.linspace(CV_MEDIAN - CV_STD, CV_MEDIAN+CV_STD, 10),np.zeros(10), np.ones(10), color="grey", alpha=0.35)
#CV_STD
#G77_STD
ax[0].set_ylim([0.0, 0.035])
ax[1].set_ylim([0.0, 0.17])


[label.set_ylabel(r"$\chi_{\nu}^2$", fontsize=14) for label in ax]
[label.set_xlabel("A(C)", fontsize=14) for label in ax]




ax[1].legend(loc='lower center', ncol=3, fancybox=True, shadow=True, bbox_to_anchor=(-0.15, -0.45))

props = dict(boxstyle='round', facecolor="white", alpha=0.5)
textstr = "G77-61\nA(C)=%.2F" % G77_MEDIAN
#ax[0].text(0.95, 1.25, textstr, transform=ax[0].transAxes, fontsize=14,
#        verticalalignment='top', bbox=props)
ax[0].text(0.30, 0.95, textstr + "+/-%.2F" %G77_STD, transform=ax[0].transAxes, fontsize=14,
        verticalalignment='top', bbox=props)


textstr = "SDSSJ1327+3335\nA(C)=%.2F" % CV_MEDIAN
#ax[1].text(0.865, 1.25, textstr, transform=ax[1].transAxes, fontsize=14,
#        verticalalignment='top', bbox=props)
ax[1].text(0.40, 0.95, textstr + "+/-%.2F" % CV_STD, transform=ax[1].transAxes, fontsize=14,
        verticalalignment='top', bbox=props)
plt.subplots_adjust(bottom=0.30, right=0.9, top=0.9, wspace=0.30, hspace=0.4)


#plt.savefig("G77_CVn_ACE_STATS.pdf", format="pdf")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
fig, ax = plt.subplots(2,2, figsize=(12,8))
palette = plt.cm.jet(np.linspace(0,1,10))

###### G77 Blue
ax[0,0].plot(G77_BLUE_RUNS['chi_square'][0].sort_values(by="temp")['temp'], 
             G77_BLUE_RUNS['chi_square'][0].sort_values(by="temp")['chi2'], color='blue', linewidth=3, alpha=0.65)

ax[0,0].plot(G77_BLUE_RUNS['chi_square'][1].sort_values(by="temp")['temp'], 
             G77_BLUE_RUNS['chi_square'][1].sort_values(by="temp")['chi2'], color='green', linewidth=3, alpha=0.65)


ax[0,0].plot(G77_BLUE_RUNS['chi_square'][2].sort_values(by="temp")['temp'], 
             G77_BLUE_RUNS['chi_square'][2].sort_values(by="temp")['chi2'], color='orange', linewidth=3, alpha=0.65)



################################################################################
'z-3.0c+1.50/', 'z-3.0c+2.0/'

ax[0,1].plot(CV_RUNS['chi_square'][0].sort_values(by="temp")['temp'], 
             CV_RUNS['chi_square'][0].sort_values(by="temp")['chi2'], color='blue', linewidth=3, alpha=0.65, label ="Group I")

ax[0,1].plot(CV_RUNS['chi_square'][1].sort_values(by="temp")['temp'], 
             CV_RUNS['chi_square'][1].sort_values(by="temp")['chi2'], color='green', linewidth=3, alpha=0.65, label ="Group II")


ax[0,1].plot(CV_RUNS['chi_square'][2].sort_values(by="temp")['temp'], 
             CV_RUNS['chi_square'][2].sort_values(by="temp")['chi2'], color='orange', linewidth=3, alpha=0.65, label ="Group III")



props = dict(boxstyle='round', facecolor="white", alpha=0.5)
textstr = "G77-61"
#ax[0].text(0.95, 1.25, textstr, transform=ax[0].transAxes, fontsize=14,
#        verticalalignment='top', bbox=props)
ax[0,0].text(0.40, 0.95, textstr, transform=ax[0,0].transAxes, fontsize=14,
        verticalalignment='top', bbox=props)


textstr = "SDSSJ1327+3335"
#ax[1].text(0.865, 1.25, textstr, transform=ax[1].transAxes, fontsize=14,
#        verticalalignment='top', bbox=props)
ax[0,1].text(0.40, 0.95, textstr, transform=ax[0,1].transAxes, fontsize=14,
        verticalalignment='top', bbox=props)







palette = plt.cm.jet(np.linspace(0,1,6))
plot_alpha=0.65
vert_alpha=0.65

ax[1,0].plot([G77_synth_array['ACE'][i] for i in G77_index], [G77_synth_array['CHI2'][i] for i in G77_index], 
           label="CHI2", color=palette[0], alpha=plot_alpha)
ax[1,0].axvline(G77_PARAMS['AC_CHI2'], color=palette[0], alpha=vert_alpha)


ax[1,1].plot([CVn_synth_array['ACE'][i] for i in CVn_index], [CVn_synth_array['CHI2'][i] for i in CVn_index], 
           label="CHI2", color=palette[0], alpha=plot_alpha)
ax[1,1].axvline(CVn_PARAMS['AC_CHI2'], color=palette[0], alpha=vert_alpha)


# ~~~~~~~~~~~~~~~~~~~~~~~~

ax[1,0].plot([G77_synth_array['ACE'][i] for i in G77_index], [G77_synth_array['CHI_FEH'][i] for i in G77_index], 
           label="CHI_FEH", color=palette[1], alpha=plot_alpha)
ax[1,0].axvline(G77_PARAMS['AC_FEH'], color=palette[1], alpha=vert_alpha)


ax[1,1].plot([CVn_synth_array['ACE'][i] for i in CVn_index], [CVn_synth_array['CHI_FEH'][i] for i in CVn_index], 
           label="CHI_FEH", color=palette[1])
ax[1,1].axvline(CVn_PARAMS['AC_FEH'], color=palette[1], alpha=vert_alpha)

# ~~~~~~~~~~~~~~~~~~~~~~~~


ax[1,0].plot([G77_synth_array['ACE'][i] for i in G77_index], [G77_synth_array['CHI_CH'][i] for i in G77_index], 
           label="CHI_CH", color=palette[2], alpha=plot_alpha)
ax[1,0].axvline(G77_PARAMS['AC_CH'], color=palette[2], alpha=vert_alpha)


ax[1,1].plot([CVn_synth_array['ACE'][i] for i in CVn_index], [CVn_synth_array['CHI_CH'][i] for i in CVn_index], 
           label="CHI_CH", color=palette[2])
ax[1,1].axvline(CVn_PARAMS['AC_CH'], color=palette[2], alpha=vert_alpha)


# ~~~~~~~~~~~~~~~~~~~~~~~~

ax[1,0].plot([G77_synth_array['ACE'][i] for i in G77_index], [G77_synth_array['CHI_WEIGHT'][i] for i in G77_index],
           color=palette[3], linestyle="--",label="CHI_WEIGHT", alpha=plot_alpha)
ax[1,0].axvline(G77_PARAMS['AC_WEIGHT'], color=palette[3], alpha=vert_alpha)


ax[1,1].plot([CVn_synth_array['ACE'][i] for i in CVn_index], [CVn_synth_array['CHI_WEIGHT'][i] for i in CVn_index],
           color=palette[3], linestyle="--",label="CHI_WEIGHT")
ax[1,1].axvline(CVn_PARAMS['AC_WEIGHT'], color=palette[3], alpha=vert_alpha)

# ~~~~~~~~~~~~~~~~~~~~~~~~


ax[1,0].plot([G77_synth_array['ACE'][i] for i in G77_index], [G77_synth_array['CHI_MEAN'][i] for i in G77_index],
           color=palette[4], linestyle="--", label="CHI_MEAN", alpha=plot_alpha)
ax[1,0].axvline(G77_PARAMS['AC_MEAN'], color=palette[4], alpha=vert_alpha)


ax[1,1].plot([CVn_synth_array['ACE'][i] for i in CVn_index], [CVn_synth_array['CHI_MEAN'][i] for i in CVn_index],
           color=palette[4], linestyle="--", label="CHI_MEAN")
ax[1,1].axvline(CVn_PARAMS['AC_MEAN'], color=palette[4], alpha=vert_alpha)


# ~~~~~~~~~~~~~~~~~~~~~~~~


ax[1,0].plot([G77_synth_array['ACE'][i] for i in G77_index], [G77_synth_array['CHI_MEDIAN'][i] for i in G77_index],
           color=palette[5], linestyle="--", label="CHI_MEDIAN", alpha=plot_alpha)
ax[1,0].axvline(G77_PARAMS['AC_MEDIAN'], color=palette[5], alpha=vert_alpha)


ax[1,1].plot([CVn_synth_array['ACE'][i] for i in CVn_index], [CVn_synth_array['CHI_MEDIAN'][i] for i in CVn_index],
           color=palette[5], linestyle="--", label="CHI_MEDIAN")
ax[1,1].axvline(CVn_PARAMS['AC_MEDIAN'], color=palette[5], alpha=vert_alpha)

# ~~~~~~~~~~~~~~~~~~~~~~~~

ax[1,0].axvline(G77_MEDIAN, color="grey", linewidth=3.)
ax[1,1].axvline(CV_MEDIAN, color="grey", linewidth=3.)

ax[1,0].fill_between(np.linspace(G77_MEDIAN - G77_STD, G77_MEDIAN+G77_STD, 10),np.zeros(10), np.ones(10), color="grey", alpha=0.35)
ax[1,1].fill_between(np.linspace(CV_MEDIAN - CV_STD, CV_MEDIAN+CV_STD, 10),np.zeros(10), np.ones(10), color="grey", alpha=0.35)
#CV_STD
#G77_STD
ax[1,0].set_ylim([0.0, 0.04])
ax[1,1].set_ylim([0.0, 0.17])


[label.set_ylabel(r"$\chi_{\nu}^2$", fontsize=14) for label in ax[1,:]]
[label.set_xlabel("A(C)", fontsize=14) for label in ax[1,:]]




ax[1,1].legend(loc='lower center', ncol=3, fancybox=True, shadow=True, bbox_to_anchor=(-0.15, -0.45))

props = dict(boxstyle='round', facecolor="white", alpha=0.5)
textstr = "G77-61\nA(C)=%.2F" % G77_MEDIAN
#ax[0].text(0.95, 1.25, textstr, transform=ax[0].transAxes, fontsize=14,
#        verticalalignment='top', bbox=props)
ax[1,0].text(0.30, 0.95, textstr + "+/-%.2F" %G77_STD, transform=ax[1,0].transAxes, fontsize=14,
        verticalalignment='top', bbox=props)


textstr = "SDSSJ1327+3335\nA(C)=%.2F" % CV_MEDIAN
#ax[1].text(0.865, 1.25, textstr, transform=ax[1].transAxes, fontsize=14,
#        verticalalignment='top', bbox=props)
ax[1,1].text(0.40, 0.95, textstr + "+/-%.2F" % CV_STD, transform=ax[1,1].transAxes, fontsize=14,
        verticalalignment='top', bbox=props)
plt.subplots_adjust(bottom=0.15, right=0.9, top=0.9, wspace=0.30, hspace=0.4)





ax[0,1].legend(loc='lower center', ncol=3, fontsize=12,fancybox=True, shadow=True, bbox_to_anchor=(-0.15, -0.25))


[label.tick_params(direction="in", top=True, right=True) for label in ax[0,:]]
[label.tick_params(direction="in", top=True, right=True) for label in ax[0,:]]
#[label.set_ylim(0.075, 0.2) for label in ax]
[label.set_ylim(0.00, 0.20) for label in ax[0,:]]


[label.set_ylabel(r"$\chi_{\nu}^2$", fontsize=14) for label in ax[0,:]]
[label.set_ylabel(r"$\chi_{\nu}^2$", fontsize=14) for label in ax[0,:]]
[label.set_xlabel(r"T$_{\rm eff}$ [K]", fontsize=13) for label in ax[0,:]]
[label.set_xlabel(r"T$_{\rm eff}$ [K]", fontsize=13) for label in ax[0,:]]

[label.tick_params(direction="in", top=True, right=True) for label in ax[:,0]]
[label.tick_params(direction="in", top=True, right=True) for label in ax[:,1]]

plt.savefig("plots/final/G77_CV_AC_STATS.pdf", format='pdf')
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
np.mean(G77_PARAMS.values())
np.mean(CVn_PARAMS.values())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-401-3dfb58df1f7e> in <module>()
# ----> 1 np.mean(G77_PARAMS.values())
#       2 np.mean(CVn_PARAMS.values())
#
# ~/miniconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    2907
#    2908     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 2909                           out=out, **kwargs)
#    2910
#    2911
#
# ~/miniconda3/lib/python3.6/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#      80             ret = ret.dtype.type(ret / rcount)
#      81     else:
# ---> 82         ret = ret / rcount
#      83
#      84     return ret
#
# TypeError: unsupported operand type(s) for /: 'dict_values' and 'int'

# %%
def MAD(input_vector):
    return np.median(np.abs(input_vector - np.median(input_vector)))/0.6349

# %%
G77_STD
# Out:
# 0.12350213596893604

# %%
CV_MEDIAN
# Out:
# 6.8400000200000006

# %%
temp = []
for current in files:
    temp.append(float(current.split("T")[1].split("g")[0]))

# %%
G77_synth_array['ACE'][np.where(G77_synth_array['CHI_MEDIAN'] == min(G77_synth_array['CHI_MEDIAN']))[0][0]]
# Out:
# 7.8458333

# %%
np.argsort(temp)
# Out:
# array([ 9, 18, 10,  2, 13,  1,  0, 16, 12,  5,  7, 11, 19, 17,  4,  6, 15,
#         8,  3, 14])

# %%
EW = [spec[spec['wave'].between(4100, 4310, inclusive=True)]['norm'].sum() for spec in specs]

# %%
plt.figure()
plt.scatter(temp,EW)
# Out:
# <img src="data:image/png;base64,..." width="640">
